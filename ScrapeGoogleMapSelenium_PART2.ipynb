# %%
# Install all the necessary python libraries if anaconda is not able to find them.

# %%
# Import all the necessary python libraries
# import requests
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import TimeoutException
from selenium.common.exceptions import NoSuchElementException

# %%
# Define CONSTANTS

# %%
# Initialize Variables
file_path = 'fnb_list_part_1.csv'
df = pd.read_csv(file_path, encoding='utf-8')
df
# Out:
#                                                    Name         Category  \
# 0                              Uncle Don's (USJ Taipan)       Halal Food
# 1                                     Malaysian Kitchen       Halal Food
# 2                       E-ONE Chinese Muslim Food Court       Halal Food
# 3                          Suhaimi Chinese Food (Halal)       Halal Food
# 4                 Mohd Chan Dim Sum @ Sunway Geo Avenue       Halal Food
# ...                                                 ...              ...
# 1445                           The Saffron Curry House.  Vegetarian Food
# 1446                                   Le Fragrant Café  Vegetarian Food
# 1447               Anjappar Indian Chettinad Restaurant  Vegetarian Food
# 1448  Restoran Melaka Street SS2 (Nyonya & Local Cui...  Vegetarian Food
# 1449                               d'Tandoor Restaurant  Vegetarian Food
#
#                Area                                            Address  \
# 0       Subang Jaya  Address: 55a, Jalan USJ 10/1f, Taipan Business...
# 1       Subang Jaya  Address: 14, Jalan SS 12/1b, Ss 12, 47500 Suba...
# 2       Subang Jaya  Address: 12, Jalan SS 15/8a, Ss 15, 47500 Suba...
# 3       Subang Jaya  Located in: Abang SS19 Food Court\nAddress: Ss...
# 4       Subang Jaya  Located in: Sunway GEO Avenue\nAddress: A-01-0...
# ...             ...                                                ...
# 1445  Petaling Jaya  Address: 3A, Jln PJU 1A/7, Ara Damansara, 4730...
# 1446  Petaling Jaya  Address: Selangor, Petaling Jaya, Taman Paramo...
# 1447  Petaling Jaya  Address: Ground Floor, 35, Jalan 14/20, Seksye...
# 1448  Petaling Jaya  Address: 34, Jalan SS 2/66, SS 2, 47300 Petali...
# 1449  Petaling Jaya  Address: 34, Jalan SS 2/66, SS 2, 47300 Petali...
#
#               Phone                                     Google Map Url  \
# 0      016-900 1074  https://www.google.com/maps/place/Uncle+Don%27...
# 1      03-5887 2805  https://www.google.com/maps/place/Malaysian+Ki...
# 2      016-614 0060  https://www.google.com/maps/place/E-ONE+Chines...
# 3               NaN  https://www.google.com/maps/place/Suhaimi+Chin...
# 4      03-5612 9939  https://www.google.com/maps/place/Mohd+Chan+Di...
# ...             ...                                                ...
# 1445   017-366 1625  https://www.google.com/maps/place/The+Saffron+...
# 1446   012-667 6867  https://www.google.com/maps/place/Le+Fragrant+...
# 1447   03-7932 1508  https://www.google.com/maps/place/Anjappar+Ind...
# 1448  011-1615 5663  https://www.google.com/maps/place/Restoran+Mel...
# 1449  011-1615 5663  https://www.google.com/maps/place/d%27Tandoor+...
#
#                           Menu Url  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ...                            ...
# 1445                           NaN
# 1446                           NaN
# 1447                           NaN
# 1448                           NaN
# 1449  https://t.me/melakastreetss2
#
#                                             Website Url  \
# 0                          http://www.uncledons.com.my/
# 1                   https://malaysiankitchen.grab.shop/
# 2                                                   NaN
# 3                                                   NaN
# 4                           http://www.mohdchan.com.my/
# ...                                                 ...
# 1445                                                NaN
# 1446                                                NaN
# 1447                           http://www.anjappar.com/
# 1448  https://restoran-melaka-streetss2.business.sit...
# 1449  https://restoran-melaka-streetss2.business.sit...
#
#                                               Order Url
# 0     https://www.foodpanda.my/restaurant/q3qh/uncle...
# 1     https://www.foodpanda.my/restaurant/y2xq/malay...
# 2                                                   NaN
# 3     https://www.foodpanda.my/restaurant/zzu1/suhai...
# 4     https://www.foodpanda.my/restaurant/xnl2/mohd-...
# ...                                                 ...
# 1445                                                NaN
# 1446  https://www.foodpanda.my/restaurant/psam/le-fr...
# 1447  https://www.foodpanda.my/restaurant/m1hf/anjap...
# 1448                                                NaN
# 1449                                                NaN
#
# [1450 rows x 9 columns]

# %%
filtered_rows = df[(df['Category'] == 'Vegetarian Food') & (df['Area'] == 'Petaling Jaya')]

num_rows = len(filtered_rows)

print(f"Number of rows: {num_rows}")
# Out:
# Number of rows: 82

# %%
driver = webdriver.Safari()
driver.maximize_window()
url = 'https://www.google.com/maps'
driver.get(url)
time.sleep(5)

# %%
def perform_search(fnb_name):

    # Locate the search box element
    search_box_element = WebDriverWait(driver, 10).until(
        EC.presence_of_element_located((By.XPATH, ''))
    )
    search_box_element.clear()
    time.sleep(0.5)
    search_box_element.send_keys(fnb_name + Keys.ENTER)

    keepScrolling=True
    while(keepScrolling):
        side_bar_element = WebDriverWait(driver, 10).until(
            EC.presence_of_element_located((By.XPATH, ''))
        )
        side_bar_element.send_keys(Keys.PAGE_DOWN)
        time.sleep(0.5)
        side_bar_element.send_keys(Keys.PAGE_DOWN)
        time.sleep(0.5)
        end_of_list_element = driver.find_element(By.TAG_NAME, "html").get_attribute('outerHTML')
        if(end_of_list_element.find("You've reached the end of the list.") != -1):
            keepScrolling = False
