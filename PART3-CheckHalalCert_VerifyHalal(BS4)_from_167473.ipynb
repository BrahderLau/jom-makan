# %%
# Install all the necessary python libraries if anaconda is not able to find them.

# WEBSITE JAKIM HALAL CACATTTTTTT

# %%
# Import all the necessary python libraries
import requests
import time
import pandas as pd
from bs4 import BeautifulSoup
from tqdm import tqdm

# %%
# Define CONSTANTS
BASE_URL = 'https://www.verifyhalal.com/Directory/PremiseDetails?premiseID='

# %%
# Initialize Variables
prod_list = []

# %%
url = (
       BASE_URL + "190141"
)

response = requests.get(url)

soup = BeautifulSoup(response.text, 'html.parser')

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="/img/VHTabIcon.jpg" rel="shortcut icon" type="image/x-icon"/>
#   <link href="../Content/bootstrap.min.css" rel="stylesheet"/>
#   <link href="https://cdn.datatables.net/1.10.19/css/dataTables.bootstrap.min.css" rel="stylesheet"/>
#   <link href="https://cdn.datatables.net/responsive/2.2.3/css/responsive.bootstrap.min.css" rel="stylesheet"/>
#   <link href="https://stackpath.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css" rel="stylesheet"/>
#   <link href="https://cdnjs.cloudflare.com/ajax/libs/semantic-ui/2.2.1/semantic.min.css" rel="stylesheet"/>
#   <script src="../../Scripts/jquery-3.6.0.min.js" type="text/javascript">
#   </script>
#   <script src="../Scripts/bootstrap.min.js" type="text/javascript">
#   </script>
#   <!---Datatables JS-->
#   <script src="../Scripts/jquery-3.6.0.js" type="text/javascript">
#   </script>
#   <script src="https://cdn.datatables.net/1.10.19/js/jquery.dataTables.min.js" type="text/javascript">
#   </script>
#   <script src="https://cdn.datatables.net/1.10.19/js/dataTables.bootstrap.min.js" type="text/javascript">
#   </script>
#   <script src="https://cdn.datatables.net/responsive/2.2.3/js/dataTables.responsive.min.js" type="text/javascript">
#   </script>
#   <script src="https://cdn.datatables.net/responsive/2.2.3/js/responsive.bootstrap.min.js" type="text/javascript">
#   </script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/semantic-ui/2.2.1/semantic.min.js">
#   </script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery-scrollTo/2.1.2/jquery.scrollTo.min.js">
#   </script>
#  </head>
#  <body>
#   <div class="wrapper">
#    <header>
#     <div id="search-bar">
#      <div class="container">
#       <div class="row" style="padding:15px 0;">
#        <div align="left" class="col-lg-2 col-md-3 col-sm-3 d-none d-sm-block">
#         <a href="/VerifyHalal/Home">
#          <div class="card" style="padding:5px 0px; margin:0px; background:none;">
#           <img alt="Card Back" class="img-back" src="/img/Logo/VH_button@4x.png" style="width:60%; max-width:100%;"/>
#           <img alt="Card Front" class="img-top" src="/img/Logo/VH_button_pushed@4x.png" style="width:60%; max-width:100%;"/>
#          </div>
#         </a>
#        </div>
#        <div align="center" class="col-lg-2 col-md-2 col-sm-2 d-block d-sm-none" hidden="">
#         <a href="/VerifyHalal/Home">
#          <div class="card" style="padding:5px 0px; margin:0px;">
#           <img alt="Card Back" class="img-back" src="/img/Logo/VH_button@4x.png" style="width:40%; max-width:100%;"/>
#           <img alt="Card Front" class="img-top2" src="/img/Logo/VH_button_pushed@4x.png" style="width:40%; max-width:100%;"/>
#          </div>
#         </a>
#        </div>
#        <div class="col-lg-6 col-md-4 col-sm-4 col-xs-8" id="custom-search-input" style="padding-top:15px;">
#         <div class="input-group col-md-12">
#          <input class="search-query form-control" id="searchText" placeholder="Search product" type="text"/>
#          <span class="input-group-btn">
#           <button class="btn btn-default" id="searchButton" onclick="getSearchAll()" style="background-color: #c1d500;" type="button">
#            <span class="fa fa-search" style="color:white;">
#            </span>
#           </button>
#          </span>
#         </div>
#        </div>
#        <div align="center" class="col-lg-2 col-md-2 col-sm-2 col-xs-4" id="custom-search-input" style="padding-top:15px;">
#         <select class="form-control" id="searchType">
#          <option value="all">
#           All
#          </option>
#          <option value="product">
#           Product
#          </option>
#          <option value="brand">
#           Brand
#          </option>
#          <option value="company">
#           Company
#          </option>
#          <option value="ingredient">
#           Ingredient
#          </option>
#          <option value="premise">
#           Premise
#          </option>
#         </select>
#        </div>
#        <div align="right" class="col-lg-2 col-md-3 col-sm-3 col-xs-3 d-none d-sm-block" style="padding-top:15px;">
#         <span id="bellLogo" onmouseleave="hvr(this, 'out')" onmouseover="hvr(this, 'in')">
#          <button class="ui button bell" col="g" style="height:35px; background-color:white; color:black;">
#           Brand Owner?
#          </button>
#          <button class="ui button bell" col="b" onclick="window.open('https://vhsmart.serunai.com/Authorization/RegisterBasicPackage','_blank')" style="height:35px; background-color:#8EB640; color:white; display:none;">
#           Register Now !
#          </button>
#         </span>
#        </div>
#        <div align="right" class="col-lg-2 col-md-3 col-sm-3 col-xs-3" style="padding-top:15px; display:none;">
#         <span id="bellLogo" onmouseleave="hvr(this, 'out')" onmouseover="hvr(this, 'in')">
#          <button class="ui button bell" col="g" style="height:35px; background-color:white; color:black; font-size:13px; padding:0; margin:0;">
#           Brand Owner?
#          </button>
#          <button class="ui button bell" col="b" onclick="window.open('https://vhsmart.serunai.com/Authorization/RegisterBasicPackage')" style="height:35px; background-color:#8EB640; color:white; display:none;">
#           Register Now !
#          </button>
#         </span>
#        </div>
#       </div>
#      </div>
#     </div>
#    </header>
#    <main>
#     <div class="thetop">
#     </div>
#     <title>
#      Premise Details
#     </title>
#     <link href="/css/verifyhalal.css?v=1.1" rel="stylesheet" type="text/css"/>
#     <style>
#      /*body {
# 		background-color: #f3f3f3;
# 	}*/
#
# 	.page-padding {
# 		padding: 50px 0;
# 	}
#
# 	.content-inside {
# 		background-color: white !important;
# 		padding: 30px 30px;
# 		border-radius: 15px;
# 	}
#
# 	/* Optional: Makes the sample page fill the window. */
#     </style>
#     <div class="page-padding" id="mainContent">
#      <div class="container">
#       <br/>
#       <br/>
#       <br/>
#       <br/>
#       <br/>
#       <div class="visible-xs">
#        <br/>
#        <br/>
#       </div>
#       <div class="col-lg-12" style="color:#878787;">
#        <a href="/VerifyHalal/Home/#pre-div">
#         <span style="color:black; text-decoration: none;">
#          Home
#         </span>
#        </a>
#        <i class="fa fa-angle-right">
#        </i>
#        <a href="/Directory/Premise">
#         <span style="color:black;">
#          Premises
#         </span>
#        </a>
#        <i class="fa fa-angle-right">
#        </i>
#        <span>
#         BANANABRO - KOTA DAMANSARA
#        </span>
#        <br/>
#        <br/>
#        <br/>
#       </div>
#       <div class="col-lg-12">
#        <h1>
#         Premises
#        </h1>
#        <br/>
#       </div>
#       <div class="col-lg-6 col-md-6 col-sm-6 col-xs-12">
#        <div id="map">
#        </div>
#       </div>
#       <div class="col-lg-6 col-md-6 col-sm-6 col-xs-12">
#        <div class="col-lg-12">
#         <span class="prodBrand" style="color: #737373;text-transform: uppercase;">
#          <b>
#           HTFU RESTAURANTS SDN. BHD.
#          </b>
#         </span>
#         <h1 class="prodName" style="margin:0;margin-top:5px;text-transform: uppercase;">
#          BANANABRO - KOTA DAMANSARA
#         </h1>
#         <br/>
#         <br/>
#        </div>
#        <table style="width:100%;">
#         <tr>
#          <td rowspan="2" style="width:10%; vertical-align:top;">
#           <div align="center">
#            <img src="/img/Icon/location.png" style="margin:0 10px; padding:0px 10px; height:auto; width:40px; max-width:100%;">
#            </img>
#           </div>
#          </td>
#          <td style="width:90%; vertical-align:top;">
#           <h4 style="margin:0 10px;">
#            Address
#           </h4>
#           <p style="margin:5px 10px;">
#            25-1 JALAN PJU 5/9 DATARAN SUNWAY KOTA DAMANSARA, PETALING JAYA
#           </p>
#          </td>
#         </tr>
#        </table>
#        <hr/>
#        <table style="width:100%;">
#         <tr>
#          <td rowspan="2" style="width:10%;">
#           <div align="center">
#            <img src="/img/Icon/cbPhone.png" style="margin:0 10px; padding:0px 10px; height:auto; width:40px; max-width:100%;">
#            </img>
#           </div>
#          </td>
#          <td style="padding-left:10px;width:20%">
#           <h4>
#            Contact
#           </h4>
#          </td>
#          <td style="padding-left:10px;width:80%">
#           <p style="margin:5px 10px;">
#            0137451533
#           </p>
#          </td>
#         </tr>
#        </table>
#        <hr/>
#        <table style="width:100%;">
#         <tr>
#          <td style="padding-left:10px;">
#           <h4>
#            Certification Body
#           </h4>
#          </td>
#         </tr>
#         <tr>
#          <td style="padding-left:10px;padding-top:5px">
#           <p>
#            Jabatan Kemajuan Islam Malaysia (JAKIM)
#           </p>
#          </td>
#         </tr>
#        </table>
#        <hr/>
#        <table style="width:100%;">
#         <tr>
#          <td style="padding-left:10px;width:20%">
#           <h4>
#            Expiry Date
#           </h4>
#          </td>
#          <td style="padding-left:10px;width:80%">
#           <p>
#            2024-09-15
#           </p>
#          </td>
#         </tr>
#        </table>
#        <hr/>
#        <table style="width:100%;">
#         <tr>
#          <td style="padding-left:10px;">
#           <h4>
#            Disclaimer
#           </h4>
#          </td>
#         </tr>
#         <tr>
#          <td style="padding-left:10px;padding-top:5px">
#           <p>
#            This premises is certified by the Halal Hub division of JAKIM. The address listed here was submitted by applicants and JAKIM is not responsible for accuracy.
#           </p>
#          </td>
#         </tr>
#        </table>
#       </div>
#      </div>
#     </div>
#     <div id="fromqr" style="width:70%; margin:70px auto; text-align:center; display:none;">
#      <i aria-hidden="true" class="fa fa-info-circle fa-2x" style="color:green;">
#      </i>
#      <p style="font-family: 'Poppins'; font-size:0.8em; margin-bottom:10%">
#       The full details of this premise Halal information can be viewed in
#       <br/>
#       Verify Halal™ app.
#       <br/>
#       <br/>
#       Get Verify Halal™ app now to verify Halal status of products, brands &amp; premises globally.
#      </p>
#      <img src="/img/Icon/qr-playstore.png" style="width:50%;">
#       <br/>
#       <a href="https://play.google.com/store/apps/details?id=com.serunai.verifyhalal">
#        <img id="GooglePlayIcon" src="/img/Icon/googleplay.png" style="width:60%;">
#        </img>
#       </a>
#       <br/>
#       <br/>
#       <img src="/img/Icon/qr-appstore.png" style="width: 50%;"/>
#       <br/>
#       <a href="https://itunes.apple.com/my/app/verify-halal/id1256351297?mt=8">
#        <img id="AppStoreIcon" src="/img/Icon/appstorePNG.png" style="width:60%;"/>
#       </a>
#      </img>
#     </div>
#     <script>
#      $(document).ready(function () {
#         if (window.location.href.indexOf("fromQR") > -1) {
#             document.getElementById("search-bar").style.display = "none";
# 			document.getElementById("mainContent").style.display = "none";
# 			document.getElementById("fromqr").style.display = "block";
#             var className = document.getElementsByClassName("footer");
#             for (i = 0; i < className.length; i++) {
#                 className[i].style.display = "none";
#             }
#         }
#     });
# 	function initMap() {
#         if (101.593339 == "0" || 101.593339 == "0") {
# 			return false;
#         }
# 			// Styles a map in night mode.
# 			var mapProp = {
# 				center: new google.maps.LatLng(101.593339, 101.593339),
# 				zoom: 15,
# 				styles: [
#             { elementType: 'geometry', stylers: [{ color: '#e1e1e1' }] },
#             //{ elementType: 'labels.text.stroke', stylers: [{ color: '#242323' }] },
#             { elementType: 'labels.text.fill', stylers: [{ color: '#746855' }] },
#             {
#             	featureType: 'administrative.locality',
#             	elementType: 'labels.text.fill',
#             	stylers: [{ color: '#d59563' }]
#             },
#             {
#             	featureType: 'poi',
#             	elementType: 'labels.text.fill',
#             	stylers: [{ color: '#afef9c' }]
#             },
#             {
#             	featureType: 'poi.park',
#             	elementType: 'geometry',
#             	stylers: [{ color: '#8dc97c' }]
#             },
#             {
#             	featureType: 'poi.park',
#             	elementType: 'labels.text.fill',
#             	stylers: [{ color: '#307f18' }]
#             },
#             {
#             	featureType: 'road',
#             	elementType: 'geometry',
#             	stylers: [{ color: '#f3f3f3' }]
#             },
#             {
#             	featureType: 'road',
#             	elementType: 'geometry.stroke',
#             	stylers: [{ color: '#e7e7e7' }]
#             },
#             {
#             	featureType: 'road',
#             	elementType: 'labels.text.fill',
#             	stylers: [{ color: '#9ca5b3' }]
#             },
#             {
#             	featureType: 'road.highway',
#             	elementType: 'geometry',
#             	stylers: [{ color: '#8d8d8d' }]
#             },
#             {
#             	featureType: 'road.highway',
#             	elementType: 'geometry.stroke',
#             	stylers: [{ color: '#777676' }]
#             },
#             {
#             	featureType: 'road.highway',
#             	elementType: 'labels.text.fill',
#             	stylers: [{ color: '#575555' }]
#             },
#             {
#             	featureType: 'transit',
#             	elementType: 'geometry',
#             	stylers: [{ color: '#2f3948' }]
#             },
#             {
#             	featureType: 'transit.station',
#             	elementType: 'labels.text.fill',
#             	stylers: [{ color: '#d59563' }]
#             },
#             {
#             	featureType: 'water',
#             	elementType: 'geometry',
#             	stylers: [{ color: '#7bc0e5' }]
#             },
#             {
#             	featureType: 'water',
#             	elementType: 'labels.text.fill',
#             	stylers: [{ color: '#5da0c5' }]
#             },
#             {
#             	featureType: 'water',
#             	elementType: 'labels.text.stroke',
#             	stylers: [{ color: '#17263c' }]
#             }
# 				]
# 			};
#
#
# 			var marker = new google.maps.Marker({
# 				position: new google.maps.LatLng(101.593339, 101.593339),
# 				map: map,
# 				icon: '/img/Icon/MarkLocation.png'
# 			});
#
# 			var map = new google.maps.Map(document.getElementById('map'), mapProp);
#
# 			marker.setMap(map);
# 	}
#     </script>
#     <script async="" defer="" src="https://maps.googleapis.com/maps/api/js?key=AIzaSyAbIz8Nt8cHufc9cFmI6rnDcqpMKdWzu3c&amp;callback=initMap">
#     </script>
#    </main>
#    <div class="footer d-none d-sm-block">
#     <div class="container">
#      <div class="row">
#       <div class="col-lg-4 col-md-4 col-sm-4 col-xs-12" style="border-right:1px solid #eee; height: 230px;">
#        <div style="padding:0px 20px;">
#         <h3>
#          ANY ENQUIRIES ?
#         </h3>
#         <div style="padding:20px 0px;">
#          <table>
#           <tr>
#            <td>
#             <img src="/img/Icon/telephone_icon2x.png" style="margin-right:20px; margin-bottom:20px; max-width:100%; width:32px; height:auto;"/>
#            </td>
#            <td>
#             <p style="margin-bottom:20px;">
#              <a href="tel:+60321817801">
#               +603-2181 7801
#              </a>
#             </p>
#            </td>
#           </tr>
#           <tr>
#            <td>
#             <img src="/img/Icon/message_icon2x.png" style="margin-right:20px; margin-bottom:20px;max-width:100%; width:32px; height:auto;"/>
#            </td>
#            <td>
#             <a href="mailto:Verifyhalal@serunai.com">
#              <p style="margin-bottom:20px; color:white;">
#               verifyhalal@serunai.com
#              </p>
#             </a>
#            </td>
#           </tr>
#          </table>
#         </div>
#        </div>
#       </div>
#       <div class="col-lg-4 col-md-4 col-sm-4 col-xs-12" style="border-right:1px solid #eee; height: 230px;">
#        <div style="padding:0px 20px;">
#         <h3>
#          VERIFY HALAL
#         </h3>
#         <div style="padding:20px 0px;">
#          <a href="/VerifyHalal/Home">
#           <p style="color:white; padding-bottom:15px;">
#            Home
#           </p>
#          </a>
#          <a href="https://verifyhalal.com/VerifyHalal/Feedback">
#           <p style="color:white; padding-bottom:15px;">
#            Complaint/Enquiry
#           </p>
#          </a>
#          <a href="https://vhsmart.serunai.com/Authorization/RegisterBasicPackage" target="_blank">
#           <p style="color:white;">
#            Brand Owner Registration
#           </p>
#          </a>
#          <br/>
#          <a href="/VerifyHalal/PrivacyPolicy" target="_blank">
#           <p style="color:white;">
#            Privacy &amp; Policy
#           </p>
#          </a>
#          <br/>
#          <a href="/VerifyHalal/MobilePrivacyPolicy" target="_blank">
#           <p style="color:white;">
#            Mobile Privacy &amp; Policy
#           </p>
#          </a>
#          <br>
#           <br>
#           </br>
#          </br>
#         </div>
#        </div>
#       </div>
#       <div class="col-lg-4 col-md-4 col-sm-4 col-xs-12">
#        <div style="padding:0px 30px;">
#         <div class="row">
#          <h3>
#           CONNECT WITH US
#          </h3>
#          <div style="padding:20px 0px;">
#           <table>
#            <tr>
#             <td>
#              <a href="https://www.facebook.com/VerifyHalalApp/" target="_blank">
#               <img src="/img/Icon/socmed/Facebook_iconW.png" style="height:auto; width:30px; max-width:100%; margin:10px 10px;"/>
#              </a>
#             </td>
#             <td>
#              <a href="https://twitter.com/halalnow" target="_blank">
#               <img src="/img/Icon/socmed/icon-x.png" style="height:auto; width:30px; max-width:100%; margin:0px 10px;"/>
#              </a>
#             </td>
#             <td>
#              <a href="https://www.instagram.com/verify_halal/" target="_blank">
#               <img src="/img/Icon/socmed/Instagram_iconW.png" style="height:auto; width:30px; max-width:100%; margin:0px 10px;"/>
#              </a>
#             </td>
#             <td>
#              <a href="https://www.youtube.com/channel/UCYukODZoWmReN-171I7qAwQ" target="_blank">
#               <img src="/img/Icon/socmed/Youtube_iconW.png" style="height:auto; width:30px; max-width:100%; margin:0px 10px;"/>
#              </a>
#             </td>
#            </tr>
#           </table>
#          </div>
#         </div>
#         <div class="row">
#          <h3>
#           DOWNLOAD OUR APP
#          </h3>
#          <div style="padding:20px 0px;">
#           <div class="row">
#            <div class="col-lg-6 col-md-6 col-sm-12">
#             <a href="https://itunes.apple.com/my/app/verify-halal/id1256351297?mt=8" target="_blank">
#              <img src="/img/Icon/appstorePNG.png" style="height:auto; width:auto; max-width:100%; margin:5px;"/>
#             </a>
#            </div>
#            <div class="col-lg-6 col-md-6 col-sm-12">
#             <a href="https://play.google.com/store/apps/details?id=com.serunai.verifyhalal" target="_blank">
#              <img src="/img/Icon/googleplay.png" style="height:auto; width:auto; max-width:100%; margin:5px;"/>
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <hr/>
#      <p style="text-align:right;">
#       Copyright © 2024
#       <a href="/VerifyHalal/Home" style="color:white;">
#        Verify Halal
#       </a>
#       . All rights reserved.
#      </p>
#     </div>
#     <div class="myQurbanRegister" style="display:none;">
#      <div>
#       <a href="https://verifyhalal.com/MyQurbanTime/Index" target="_blank">
#        <img src="/img/MyQurbanTime/btn-webRegister.png"/>
#       </a>
#      </div>
#     </div>
#     <div class="scrolltop">
#      <div class="scroll icon">
#       <i class="fa fa-4x fa-angle-up">
#       </i>
#      </div>
#     </div>
#    </div>
#    <div class="footer d-block d-sm-none">
#     <div class="container">
#      <div class="row">
#       <div align="center" class="col-xs-12">
#        <div style="padding:0px 20px;">
#         <h3>
#          ANY ENQUIRIES ?
#         </h3>
#         <div style="padding:20px 0px;">
#          <table>
#           <tr>
#            <td>
#             <img src="/img/Icon/telephone_icon2x.png" style="margin-right:20px; margin-bottom:20px; max-width:100%; width:32px; height:auto;"/>
#            </td>
#            <td>
#             <p style="margin-bottom:20px;">
#              <a href="tel:+60321817801">
#               +603-2181 7801
#              </a>
#             </p>
#            </td>
#           </tr>
#           <tr>
#            <td>
#             <img src="/img/Icon/message_icon2x.png" style="margin-right:20px; margin-bottom:20px;max-width:100%; width:32px; height:auto;"/>
#            </td>
#            <td>
#             <a href="mailto:Verifyhalal@serunai.com">
#              <p style="margin-bottom:20px; color:white;">
#               verifyhalal@serunai.com
#              </p>
#             </a>
#            </td>
#           </tr>
#          </table>
#         </div>
#        </div>
#       </div>
#       <div align="center" class="col-xs-12">
#        <div style="padding:0px 20px;">
#         <h3>
#          VERIFY HALAL
#         </h3>
#         <div style="padding:20px 0px;">
#          <a href="/VerifyHalal/Home">
#           <p style="color:white; padding-bottom:15px;">
#            Home
#           </p>
#          </a>
#          <a href="https://verifyhalal.com/VerifyHalal/Feedback">
#           <p style="color:white; padding-bottom:15px;">
#            Complaint/Enquiry
#           </p>
#          </a>
#          <a href="https://vhsmart.serunai.com/Authorization/RegisterBasicPackage" target="_blank">
#           <p style="color:white;">
#            Brand Owner Registration
#           </p>
#          </a>
#          <br/>
#         </div>
#        </div>
#       </div>
#       <div align="center" class="col-xs-12">
#        <div style="padding:0px 30px;">
#         <div class="row">
#          <h3>
#           CONNECT WITH US
#          </h3>
#          <div style="padding:20px 0px;">
#           <table>
#            <tr>
#             <td>
#              <a href="https://www.facebook.com/VerifyHalalApp/" target="_blank">
#               <img src="/img/Icon/socmed/Facebook_iconW.png" style="height:auto; width:30px; max-width:100%; margin:10px 10px;"/>
#              </a>
#             </td>
#             <td>
#              <a href="https://twitter.com/halalnow" target="_blank">
#               <img src="/img/Icon/socmed/icon-x.png" style="height:auto; width:30px; max-width:100%; margin:0px 10px;"/>
#              </a>
#             </td>
#             <td>
#              <a href="https://www.instagram.com/verify_halal/" target="_blank">
#               <img src="/img/Icon/socmed/Instagram_iconW.png" style="height:auto; width:30px; max-width:100%; margin:0px 10px;"/>
#              </a>
#             </td>
#             <td>
#              <a href="https://www.youtube.com/channel/UCYukODZoWmReN-171I7qAwQ" target="_blank">
#               <img src="/img/Icon/socmed/Youtube_iconW.png" style="height:auto; width:30px; max-width:100%; margin:0px 10px;"/>
#              </a>
#             </td>
#            </tr>
#           </table>
#          </div>
#         </div>
#         <div class="row">
#          <h3>
#           DOWNLOAD OUR APP
#          </h3>
#          <div style="padding:20px 0px;">
#           <div class="row">
#            <div class="col-xs-12">
#             <a href="https://itunes.apple.com/my/app/verify-halal/id1256351297?mt=8" target="_blank">
#              <img src="/img/Icon/appstorePNG.png" style="height:50px; width:auto; max-width:100%; margin:5px;"/>
#             </a>
#            </div>
#            <div class="col-xs-12">
#             <a href="https://play.google.com/store/apps/details?id=com.serunai.verifyhalal" target="_blank">
#              <img src="/img/Icon/googleplay.png" style="height:50px; width:auto; max-width:100%; margin:5px;"/>
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <p style="text-align:center; color:#808080;">
#       Copyright © 2024
#       <a href="/VerifyHalal/Home" style="color:#808080;">
#        Verify Halal
#       </a>
#       . All rights reserved.
#      </p>
#     </div>
#    </div>
#   </div>
#   <div class="container">
#    <!-- Trigger the modal with a button -->
#    <!-- Feedback Modal -->
#    <div class="modal fade" id="FeedbackModal" role="dialog">
#     <div class="modal-dialog">
#      <form action="/VerifyHalal/SubmitFeedback" class="ui form" method="post">
#       <!-- Modal content-->
#       <div class="modal-content">
#        <div class="modal-header" style="background-color:#1f1f1f; border-radius:5px 5px 0px 0px;">
#         <button class="close" data-bs-dismiss="modal" type="button">
#          ×
#         </button>
#         <h4 class="modal-title" style="color:white">
#          Verify Halal Feedback
#         </h4>
#        </div>
#        <p style="text-align:center">
#         <img id="loader" src="/img/ajax-loader.gif" style="padding:50px; display:none;"/>
#        </p>
#        <div class="modal-body">
#         <div id="preFeed">
#          <h4>
#           Verify Halal Global Community Support.
#          </h4>
#          You can express your feedback or enquiries related to Halal
#                                 and it will be submitted to relevant authorities (e.g JAKIM, THIDA, etc.)
#                                 for further action.
#          <hr/>
#          <div class="row">
#           <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12">
#            <label>
#             Select Category
#             <span style="color:red">
#              *
#             </span>
#             :
#            </label>
#            <select class="form-control" id="category">
#             <option value="Enquiry">
#              Enquiry
#             </option>
#             <option value="Complaint">
#              Complaint
#             </option>
#             <option value="Comment">
#              Comment
#             </option>
#             <option value="Suggestion">
#              Suggestion
#             </option>
#            </select>
#            <label class="errorMessage" id="errorCategory" style="display: none;color:#B70D0D;float:right;font-size:11px">
#             This field is required
#            </label>
#            <br/>
#           </div>
#           <div class="col-lg-6 col-md-6 col-sm-6 col-xs-12">
#            <label>
#             Name
#             <span style="color:red">
#              *
#             </span>
#             <small>
#              (Complainant)
#             </small>
#             :
#            </label>
#            <input class="form-control" id="name" type="text"/>
#            <label class="errorMessage" id="errorName" style="display: none;color:#B70D0D;float:right;font-size:11px">
#             This field is required
#            </label>
#            <br/>
#           </div>
#           <div class="col-lg-6 col-md-6 col-sm-6 col-xs-12">
#            <label>
#             NRIC/Passport
#             <small>
#              (Complainant)
#             </small>
#             :
#            </label>
#            <input class="form-control" id="UserID" type="text"/>
#            <br/>
#           </div>
#           <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12">
#            <label>
#             Address
#             <small>
#              (Complainant)
#             </small>
#             :
#            </label>
#            <textarea class="form-control" cols="50" id="address" rows="3"></textarea>
#            <br/>
#           </div>
#           <div class="row">
#            <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12">
#             <div class="col-lg-6 col-md-6 col-sm-6 col-xs-12">
#              <label>
#               Email
#               <span style="color:red">
#                *
#               </span>
#               <small>
#                (Complainant)
#               </small>
#               :
#              </label>
#              <input class="form-control" id="email" onkeyup="return checkEmail();" type="text"/>
#              <label class="errorMessage" id="errorEmail" style="display: none;color:#B70D0D;float:right;font-size:11px">
#               This field is required
#              </label>
#              <label class="errorMessage" id="errorEmailFormat" style="display: none;color:#B70D0D;float:right;font-size:11px">
#               Please provide a valid email address
#              </label>
#              <br/>
#             </div>
#             <div class="col-lg-6 col-md-6 col-sm-6 col-xs-12">
#              <label>
#               Contact Number
#               <small>
#                (Complainant)
#               </small>
#               :
#              </label>
#              <input class="form-control" id="contactNo" type="text"/>
#              <br/>
#             </div>
#            </div>
#           </div>
#           <div class="row">
#            <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12">
#             <div class="col-lg-6 col-md-6 col-sm-6 col-xs-12">
#              <label>
#               Nationality
#               <span style="color:red">
#                *
#               </span>
#               :
#              </label>
#              <select class="form-control" id="nationality">
#              </select>
#              <label class="errorMessage" id="errorNationality" style="display: none;color:#B70D0D;float:right;font-size:11px">
#               This field is required
#              </label>
#              <br/>
#             </div>
#             <div class="col-lg-6 col-md-6 col-sm-6 col-xs-12">
#              <label>
#               Location
#               <small>
#                (Complainee)
#               </small>
#               :
#              </label>
#              <input class="form-control" id="location" type="text"/>
#              <br/>
#             </div>
#            </div>
#           </div>
#           <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12">
#            <label>
#             Enter details of the complaint here,
#                                             not more than 1000 characters
#             <span style="color:red">
#              *
#             </span>
#            </label>
#            <textarea class="form-control" cols="50" id="comment" maxlength="1000" rows="4"></textarea>
#            <small id="textarea_feedback" style="color:#878787; float:right;font-size:12px; margin-top:5px;">
#            </small>
#            <label class="errorMessage" id="errorComment" style="display: none;color:#B70D0D;float:right;font-size:11px">
#             This field is required
#            </label>
#            <br/>
#           </div>
#          </div>
#         </div>
#         <div id="postFeed" style="display:none;">
#          <h4>
#           Verify Halal Global Community Support.
#          </h4>
#          <p>
#           Your feedback has been submitted successfully.
#          </p>
#         </div>
#         <div id="failedFeed" style="display:none;">
#          <h4>
#           Verify Halal Global Community Support.
#          </h4>
#          <p>
#           Unable to submit your feedback. Please try again, or contact Technical team.
#          </p>
#         </div>
#        </div>
#        <div class="modal-footer">
#         <div class="ui buttons" style="float:right;">
#          <button class="ui green button" onclick="return FeedbackValidation() &amp;&amp; submitFeedbackForm()" type="button">
#           Submit
#          </button>
#          <button class="ui default button" data-bs-dismiss="modal" style="color:black;" type="button">
#           Cancel
#          </button>
#         </div>
#        </div>
#       </div>
#      </form>
#     </div>
#    </div>
#    <!-- Modal -->
#    <div class="modal fade" id="DownloadVHModal" role="dialog">
#     <div class="modal-dialog">
#      <!-- Modal content-->
#      <div class="modal-content">
#       <div class="modal-header" style="background-color:#1f1f1f; border-radius:5px 5px 0px 0px;">
#        <button class="close" data-bs-dismiss="modal" type="button">
#         ×
#        </button>
#        <h4 class="modal-title" style="color:white">
#         Download Verify Halal™ Mobile App
#        </h4>
#       </div>
#       <p style="text-align:center">
#        <img id="loader" src="/img/ajax-loader.gif" style="padding:50px; display:none;"/>
#       </p>
#       <div class="modal-body">
#        <div class="row" style="text-align:center">
#         <div class="col-md-12">
#          <p>
#           Get Verify Halal™ Mobile App now to verify Halal status of products, brands &amp; premises globally.
#          </p>
#         </div>
#        </div>
#        <br/>
#        <div class="row">
#         <div class="col-md-6" style="text-align:center">
#          <img src="/img/Icon/qr-playstore.png" style="width:150px; height:auto;"/>
#          <br/>
#          <a href="https://play.google.com/store/apps/details?id=com.serunai.verifyhalal" target="_blank">
#           <img src="/img/Icon/googleplay.png" style="height:auto; width:auto; max-width:60%; margin:5px;"/>
#          </a>
#         </div>
#         <div class="col-md-6" style="text-align:center">
#          <img src="/img/Icon/qr-appstore.png" style="width:150px; height:auto;"/>
#          <br/>
#          <a href="https://itunes.apple.com/my/app/verify-halal/id1256351297?mt=8" target="_blank">
#           <img src="/img/Icon/appstorePNG.png" style="height:auto; width:auto; max-width:60%; margin:5px;"/>
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>
# <script>
#  function hvr(dom, action) {
#         if (action == 'in') {
#             $(dom).find("[col=g]").css("display", "none");
#             $(dom).find("[col=b]").css("display", "inline-block");
#         }
#
#         else {
#             $(dom).find("[col=b]").css("display", "none");
#             $(dom).find("[col=g]").css("display", "inline-block");
#         }
#     }
# </script>
# <script>
#  $(document).ready(function () {
#         $('#searchText').keydown(function (e) {
#             if (e.which == 13) {
#                 $("#searchButton").click();
#             }
#         });
#     });
#
#
#     function getSearchAll() {
#
#         if ($("#searchText").val() != "") {
#
#             searchVal = $("#searchText").val();
#             searchType = $("#searchType").val();
#             window.location = '/Directory/SearchResult?searchVal=' + searchVal + '&searchType=' + searchType;
#
#         }
#         else {
#
#             $('#searchText').attr("placeholder", "Please enter your search keyword");
#             $('#searchText').addClass('place-red');
#         }
#     }
# </script>
# <script>
#  $(window).scroll(function () {
#         if ($(this).scrollTop() > 50) {
#             $('.scrolltop:hidden').stop(true, true).fadeIn();
#         } else {
#             $('.scrolltop').stop(true, true).fadeOut();
#         }
#     });
#     $(function () { $(".scroll").click(function () { $("html,body").animate({ scrollTop: $(".thetop").offset().top }, "1000"); return false }) })
# </script>

# %%
# Find Product Brand & Product Name

prod_brand_element = soup.find('span', class_='prodBrand')
prod_name_element = soup.find('h1', class_='prodName')

if prod_brand_element:
    print(prod_brand_element.text)
    print(prod_name_element.text)
else:
    print("Element not found")
# Out:
# HTFU RESTAURANTS SDN. BHD.
# BANANABRO - KOTA DAMANSARA

# %%
# Find Address
address_h4 = soup.find('h4', string="Address")

if address_h4:
    address = address_h4.find_next_sibling('p')
    if address:
        address = address.text.strip() 
        print(address)
    else:
        print("Value of address not found.")
else:
    print("Address not found.")
# Out:
# 25-1 JALAN PJU 5/9 DATARAN SUNWAY KOTA DAMANSARA, PETALING JAYA

# %%
# Find Expiry Date
expiry_date_h4 = soup.find('h4', string='Expiry Date')
if expiry_date_h4:
    next_td_expiry_date = expiry_date_h4.find_parent('td').find_next_sibling('td')
    if next_td_expiry_date:
        expiry_date = next_td_expiry_date.text.strip()
        print(expiry_date)
    else:
        print("Value of expiry date not found.")
else:
    print("Expiry Date not found.")
# Out:
# 2024-09-15

# %%
# Find Certificate Body
certification_body_h4 = soup.find('h4', string='Certification Body')
if certification_body_h4:
    next_tr_certification_body = certification_body_h4.find_parent('tr').find_next_sibling('tr')
    if next_tr_certification_body:
        certification_body = next_tr_certification_body.text.strip()
        print(certification_body)
    else:
        print("Value of certification body not found.")
else:
    print("Certification Body not found.")
# Out:
# Jabatan Kemajuan Islam Malaysia (JAKIM)

# %%
def parse_and_save_details(response_text, premise_id):
    soup = BeautifulSoup(response_text, 'html.parser')
    prod_brand = ''
    prod_name = ''
    prod_address = '' 
    prod_halal_cert_date = '' 
    prod_halal_cert_body = ''

    # Product Brand

    try:
        prod_brand_span = soup.find('span', class_='prodBrand')
        if prod_brand_element:
            prod_brand = prod_brand_span.text
        else:
            prod_brand = None
    except Exception:
        prod_brand = None
        pass

    # Product Name

    try:
        prod_name_h1 = soup.find('h1', class_='prodName')
        if prod_brand_element:
            prod_name = prod_name_h1.text
        else:
            prod_name = None
    except Exception:
        prod_name = None
        pass 

    # Address

    try:
        address_h4 = soup.find('h4', string="Address")
        if address_h4:
            next_p_address = address_h4.find_next_sibling('p')
            if next_p_address:
                prod_address = next_p_address.text.strip() 
            else:
                prod_address = None
        else:
            prod_address = None
    except Exception:
        prod_address = None
        pass

    # Product Halal Certificate Date

    try:
        expiry_date_h4 = soup.find('h4', string='Expiry Date')
        if expiry_date_h4:
            next_td_expiry_date = expiry_date_h4.find_parent('td').find_next_sibling('td')
            if next_td_expiry_date:
                prod_halal_cert_date = next_td_expiry_date.text.strip() 
            else:
                prod_halal_cert_date = None
        else:
            prod_halal_cert_date = None
    except Exception:
        prod_halal_cert_date = None
        pass 

    # Product Halal Certificate Date

    try:
        certification_body_h4 = soup.find('h4', string='Certification Body')
        if expiry_date_h4:
            next_tr_certification_body = certification_body_h4.find_parent('tr').find_next_sibling('tr')
            if next_tr_certification_body:
                prod_halal_cert_body = next_tr_certification_body.text.strip()
            else:
                prod_halal_cert_body = None
        else:
            prod_halal_cert_body = None
    except Exception:
        prod_halal_cert_body = None
        pass

    prod_details = {
        "Premise Name": prod_name,
        "Company Brand Name": prod_brand,
        "Address": prod_address,
        "Halal Certification Expiry Date": prod_halal_cert_date,
        "Halal Certification Body": prod_halal_cert_body
    }
    #tqdm.write(f'Premise ID: {premise_id}, Data: {prod_details}')
    #prod_list.append(prod_details)
    #df = pd.DataFrame(prod_details)
    #df.append(prod_details, ignore_index=True)
    pd.DataFrame([prod_details]).to_csv('premis_makanan_list_part_3_from_167473.csv',mode='a',index=False,header=False,encoding='utf-8')

# %%
for premise_id in tqdm(range(167473, 200000), desc="Fetching premises"):
    formatted_premise_id = f"{premise_id:06}"
    url = f"{BASE_URL}{formatted_premise_id}"
    
    try:
        response = requests.get(url)
        if response.status_code == 200:
            parse_and_save_details(response.text, formatted_premise_id)
        else:
            print(f"Page not found for premiseID={formatted_premise_id}, status code: {response.status_code}")
    except requests.exceptions.RequestException as e:
        print(f"Request failed for premiseID={formatted_premise_id}, error: {e}")
        break
    
    time.sleep(0.5)  # Sleep for 0.5 second to be polite and not overwhelm the server :)
# Out:
# Fetching premises: 100%|██████████| 32527/32527 [6:05:54<00:00,  1.48it/s]

# %%
#df = pd.DataFrame(prod_list)

# %%
#df.to_csv('premis_makanan_list_part_3.csv',mode='a',index=False,header=False,encoding='utf-8')
