# %%
from rapidfuzz import process, fuzz
import pandas as pd
import numpy as np
from tqdm import tqdm
import re

# %%
# Function to find the first two numbers in the address
def find_first_number(address):
    match = re.search(r'\d+', address)
    return int(match.group()) if match else None

def find_first_two_numbers(address):
    matches = re.findall(r'\d+', address)
    return matches[:2] if len(matches) >= 2 else None

# %%
# Function to normalize the text to check the similarity as best as it could
def normalize_text(text):
    # Ensure the text is in string format
    text_string = str(text)
    # Remove all special characters
    normalized_text = re.sub(r'[^\w\s]', '', text_string)
    return normalized_text.upper()  # Convert to uppercase for consistency

# %%
def check_no_word_matches(field1, field2):
    # Split both fields into sets of words, converting everything to lowercase to ensure case-insensitive comparison
    words_field1 = set(field1.lower().split())
    words_field2 = set(field2.lower().split())
    
    # Check for intersection
    if words_field1.isdisjoint(words_field2):
        return True  # No words match
    else:
        return False  # There is at least one matching word

# %%
# testing

df_fnb = pd.read_csv('csv_data/fnb_list_part_2_cleaned.csv', encoding='utf-8')
df_halal = pd.read_csv('csv_data/premis_makanan_list_part_4_cleaned.csv', encoding='utf-8')

# Combine 'Name' and 'Address' into a single string for matching
df_fnb['Combined'] = df_fnb.apply(lambda row: normalize_text(row['Name'] + ' ' + normalize_text(row['Address'])), axis=1)
df_halal['Combined'] = df_halal.apply(lambda row: normalize_text(row['Premise Name'] + ' ' + normalize_text(row['Address'])), axis=1)

THRESHOLD = 81.5
#SKIP_CHECKING_THRESHOLD = 89
MAX_MATCHES = 30
matches = []

for index, fnb_row in tqdm(df_fnb.iterrows(), total=df_fnb.shape[0], desc="Searching for matches"):
    # Extract the combined field for the current row
    combined_fnb = fnb_row['Combined']
    
    # Perform fuzzy matching against the combined fields of df_halal
    best_match = process.extractOne(combined_fnb, df_halal['Combined'].tolist(), scorer=fuzz.token_set_ratio)
    
    # Check if the best match score meets the threshold
    if best_match and best_match[1] >= THRESHOLD:
        
        # Retrieve the matching row from df_halal
        halal_row = df_halal[df_halal['Combined'] == best_match[0]].iloc[0]

        normalized_fnb_name = normalize_text(fnb_row['Name'])
        normalized_fnb_address =  normalize_text(fnb_row['Address'])
        normalized_halal_name = normalize_text(halal_row['Premise Name'])
        normalized_halal_address =  normalize_text(halal_row['Address'])

        # Check if halal row address length is extremely shorter compared to fnb row address
        if len(fnb_row['Address'])/3 > len(halal_row['Address']):
            if len(matches) >= MAX_MATCHES:
                break
            else:
                continue

        # Check if both fnb name and halal nama really no common words at all 
        if check_no_word_matches(normalized_fnb_name,normalized_halal_name) == True:
            if len(matches) >= MAX_MATCHES:
                break
            else:
                continue
    
        # Check if fnb name and premise name are exactly the same
        if (normalized_fnb_name.replace(' ', '') == normalized_halal_name.replace(' ', '')):#fuzz.token_set_ratio(normalized_fnb_name, normalized_halal_name) >= 99) and ):
            matches.append((fnb_row['Name'], fnb_row['Address'], halal_row['Premise Name'], halal_row['Address'], best_match[1]))
            if len(matches) >= MAX_MATCHES:
                break
            else:
                continue

        # if best_match and best_match[1] < SKIP_CHECKING_THRESHOLD:
        # Check whether if the first two detected numbers in fnb address is equivalent to premise address
        first_two_numbers_in_fnb_address = find_first_two_numbers(normalized_fnb_address)
        first_two_numbers_in_halal_address = find_first_two_numbers(normalized_halal_address)
        # Check whether if the first number in fnb address is equivalent to premise address
        first_number_in_fnb_address = find_first_number(normalized_fnb_address)
        first_number_in_halal_address = find_first_number(normalized_halal_address)

        if (first_two_numbers_in_fnb_address != None and first_two_numbers_in_halal_address != None):
            if first_two_numbers_in_fnb_address == first_two_numbers_in_halal_address:
                matches.append((fnb_row['Name'], fnb_row['Address'], halal_row['Premise Name'], halal_row['Address'], best_match[1]))
            # Break if maximum matches are found
            if len(matches) >= MAX_MATCHES:
                break
            else:
                continue
        
        if (first_number_in_fnb_address != None and first_number_in_halal_address != None):
            if first_number_in_fnb_address == first_number_in_halal_address:
                matches.append((fnb_row['Name'], fnb_row['Address'], halal_row['Premise Name'], halal_row['Address'], best_match[1]))
                # Break if maximum matches are found
            if len(matches) >= MAX_MATCHES:
                break
            else:
                continue
        # else:
        #     matches.append((fnb_row['Name'], fnb_row['Address'], halal_row['Premise Name'], halal_row['Address'], best_match[1]))
        # Break if maximum matches are found
        if len(matches) >= MAX_MATCHES:
            break

# Print matches
for match in matches[:MAX_MATCHES]:
    print(f"FNB Name: {match[0]}") 
    print(f"FNB Address: {match[1]}")
    print(f"Premise Name: {match[2]}")
    print(f"Premise Address: {match[3]}")
    print(f"Match Score: {match[4]}\n")
# Out:
# Searching for matches:  11%|█▏        | 459/4070 [00:15<02:05, 28.87it/s]
# FNB Name: 4Fingers Crispy Chicken @ Puchong Utama
# FNB Address: Pusat No, 20 (GF, Jalan PU 7/2, Bandar Puchong Utama, 47140 Puchong, Selangor
# Premise Name: 4FINGERS CRISPY CHICKEN PUCHONG UTAMA
# Premise Address: 20 (GF), JALAN PU 7/2,  TAMAN PUCHONG UTAMA, PUCHONG
# Match Score: 94.82758620689656
#
# FNB Name: A&W BMC Mall
# FNB Address: Lot G-16, Ground Floor BMC Mall, Jalan Temenggung 21/9, Bandar Mahkota Cheras, 43200 Cheras, Selangor
# Premise Name: A&W BMC MALL
# Premise Address: LOT G-16, GROUND FLOOR BMC MALL, JALAN TEMENGGUNG 21/9, BANDAR MAHKOTA CHERAS
# Match Score: 100.0
#
# FNB Name: A&W C180 Cheras Selatan
# FNB Address: 3A & 5,Jalan C180/1, Bt 11 Cheras, 43200 Balakong, Selangor
# Premise Name: A&W C180 CHERAS SELATAN
# Premise Address: 3A & 5,JALAN C180/1, BT 11 CHERAS
# Match Score: 100.0
#
# FNB Name: A&W Citta Mall
# FNB Address: Citta Mall, G-10 Ground Floor, Jalan PJU 1a/48, Pusat Perdagangan Dana 1, 47301 Petaling Jaya, Selangor
# Premise Name: A&W CITTA MALL
# Premise Address: G-10, GROUND FLOOR, CITTA MALL, JALAN PJU 1A/48, PUSAT PERDAGANGAN DANA 1, PETALING JAYA
# Match Score: 100.0
#
# FNB Name: A&W Da Men Mall
# FNB Address: LG-19, DaMen Mall, Persiaran Kewajipan, Usj 1, 47600 Subang Jaya, Selangor
# Premise Name: A&W DAMEN MALL
# Premise Address: LG-19 DAMEN MALL PERSIARAN KEWAJIPAN, USJ 1
# Match Score: 100.0
#
# FNB Name: A&W IOI Mall Puchong
# FNB Address: Ioi Mall, EF13 - EF13A & EF13AA, First Floor, Batu 9, 47100 Puchong, Selangor
# Premise Name: A&W IOI PUCHONG
# Premise Address: EF13 - EF13A & EF13AA, FIRST FLOOR, IOI MALL BANDAR PUCHONG JAYA, PUCHONG
# Match Score: 89.0909090909091
#
# FNB Name: A&W PJ Palms Sports Centre
# FNB Address: PJ Palms Sport Centre, No 1, Lorong Sultan, Pjs 52, 46000 Petaling Jaya, Selangor
# Premise Name: A&W PJ PALMS
# Premise Address: PJ PALMS SPORT CENTRE NO 1 LORONG SULTAN PETALING JAYA
# Match Score: 100.0
#
# FNB Name: A&W Petaling Jaya
# FNB Address: No 9, Lorong Sultan, Pjs 52, 46000 Petaling Jaya, Selangor
# Premise Name: A&W P.J DRIVE IN
# Premise Address: NO 9 LORONG SULTAN PETALING JAYA SELANGOR
# Match Score: 88.0
#
# FNB Name: A&W Sunway Velocity
# FNB Address: B-21A,Basement 1, Sunway Velocity, Lingkaran Sunway Velocity, Maluri, 55100 Kuala Lumpur
# Premise Name: A&W SUNWAY VELOCITY
# Premise Address: B-21A, BASEMENT 1 SUNWAY VELOCITY LINGKARAN SV MALURI KUALA LUMPUR
# Match Score: 92.6470588235294
#
# FNB Name: A&W Syopz Mall, Taylor's Lakeside Campus
# FNB Address: Lot G-07, Level G, Syopz Mall, The Boardwalk, No.2, Jalan Taylor's, 47500, Subang Jaya, Selangor
# Premise Name: A&W SYOPZ MALL
# Premise Address: LOT G-07, LEVEL G, SYOPZ MALL, THE BOARDWALK, NO.2, JALAN TAYLOR'S,
# Match Score: 100.0
#
# FNB Name: A&W USJ Taipan
# FNB Address: Wisma Uep, No. 5, Jalan USJ 10/1a, Subang Square, 47620 Subang Jaya, Selangor
# Premise Name: A&W USJ TAIPAN
# Premise Address: 5, JALAN USJ 10/1A USJ 10, UEP SUBANG JAYA
# Match Score: 96.55172413793103
#
# FNB Name: Al Amber Chinese Muslim Restaurant
# FNB Address: Unit 14, Level 1, Nexus, 7, Jalan Kerinchi, Bangsar South, 59200 Kuala Lumpur, Wilayah Persekutuan Kuala Lumpur
# Premise Name: AL-AMBER CHINESE MUSLIM RESTAURANT
# Premise Address: UNIT 1-14, NEXUS BANGSAR SOUTH, NO. 7, JALAN KERINCHI,
# Match Score: 89.93288590604027
#
# FNB Name: Asian Recipe Sdn. Bhd.
# FNB Address: Monash University Sunway Campus, Jalan Lagoon Selatan, Bandar Sunway, Selangor, 46150 Petaling Jaya
# Premise Name: ASIAN RECIPE SDN. BHD.
# Premise Address: MONASH UNIVERSITY SUNWAY CAMPUS, JALAN LAGOON SELATAN, BANDAR SUNWAY
# Match Score: 100.0
#
# FNB Name: BananaBro @Kota Damansara (HALAL Certified)
# FNB Address: 25-1, Jalan PJU 5/9, Dataran Sunway, Kota Damansara, 47810 Petaling Jaya, Selangor
# Premise Name: BANANABRO - KOTA DAMANSARA
# Premise Address: 25-1 JALAN PJU 5/9 DATARAN SUNWAY KOTA DAMANSARA, PETALING JAYA
# Match Score: 100.0
#
# FNB Name: BananaBro Bandar Sri Permaisuri (Halal Certified)
# FNB Address: R-G-22, Tingkat G, Q- Avenue, Kompleks Permaisuri Q, 6, Jalan Sri Permaisuri, Bandar Sri Permaisuri, 56000 Kuala Lumpur, Wilayah Persekutuan Kuala Lumpur
# Premise Name: BANANABRO BANDAR SRI PERMAISURI
# Premise Address: R-G-22, TINGKAT G, Q-AVENUE, KOMPLEKS PERMAISURI Q,   NO. 6, JALAN SRI PERMAISURI,
# Match Score: 92.19858156028369
#
# FNB Name: BananaBro Cheras Leisure Mall (Halal Certified)
# FNB Address: Leisure Mall Complex, L1-60A, 1st Floor, Jalan Manis 6, Taman Segar, Taman Gemilang, 56100 Kuala Lumpur, Wilayah Persekutuan
# Premise Name: BANANABRO CHERAS LEISURE MALL
# Premise Address: LEISURE MALL COMPLEX L1-60A, 1ST FLOOR, JALAN MANIS 6 TAMAN SEGAR
# Match Score: 100.0
#
# FNB Name: Bask Bear Coffee The Grand SS15
# FNB Address: G10 (Ground Floor), Grand Subang Jaya, Jalan SS 15/8A Subang Jaya, 47500 Selangor
# Premise Name: BB COFFEE SDN BHD - THE GRAND SS15
# Premise Address: G10 (GROUND FLOOR), GRAND SUBANG JAYA,  JALAN SS 15/8A, SS15,
# Match Score: 92.0863309352518
#
# FNB Name: Berry's Cake House (Bandar Puchong Jaya)
# FNB Address: Block E, Puchong-ioi Boulevard, E-G-25, Jalan Kenari 6, Bandar Puchong Jaya, 47100 Puchong, Selangor
# Premise Name: BERRY'S CAKE HOUSE (KL) SB IOI BOULEVARD
# Premise Address: E-G-25, BLOK E, IOI BOULEVARD JALAN KENARI 6, BANDAR PUCHONG JAYA
# Match Score: 90.19607843137254
#
# FNB Name: Brass Cafe
# FNB Address: Lorong Utara A, 12, Jln Utara, 46200 Petaling Jaya, Selangor
# Premise Name: COFFEE HOUSE - BRASS CAFE
# Premise Address: CRYSTAL CROWN HOTEL, NO 12 LORONG UTARA, OFF JLN UTARA, 46200 PETALING JAYA, SELANGOR
# Match Score: 98.33333333333333
#
# FNB Name: Bread Buddy
# FNB Address: 118g, Jalan PUJ 3/2, Puj 3, 43300 Seri Kembangan, Selangor
# Premise Name: BREAD BUDDY PLT
# Premise Address: 118-G JALAN PUJ 3/2 TAMAN PUNCAK JALIL SERI KEMBANGAN
# Match Score: 83.80952380952381
#
# FNB Name: Burger King Amerin Mall
# FNB Address: Lot G-6 (GF), Amerin Mall, Persiaran Impian Indah, Taman Impian Indah, 43300 Seri Kembangan, Selangor
# Premise Name: BURGER KING AMERIN MALL
# Premise Address: LOT G-6, THE AMERIN MALL, TAMAN IMPIAN INDAH, SERI KEMBANGAN,
# Match Score: 96.96969696969697
#
# FNB Name: Burger King Bandar Tun Hussein Onn
# FNB Address: Lot No. 16 & 17 (G, Jln Suarasa 8/5, Tun Hussein Onn, 43200 Cheras, Selangor
# Premise Name: BURGER KING BANDAR TUN HUSSEIN ONN
# Premise Address: LOT NO.16(G) & 17(G) JALAN SUARASA 8/5, BANDAR TUN HUSSEIN ONN, CHERAS
# Match Score: 87.5
#
# FNB Name: Burger King Caltex Cheras
# FNB Address: Lot 27681 & 27682, Batu, 6, Jln Cheras, 56000 Cheras, Selangor
# Premise Name: BURGER KING CALTEX CHERAS
# Premise Address: CALTEX PETROL FILLING STATION, LOT 27681 & 27682, BATU 6 JALAN CHERAS-KAJANG,
# Match Score: 83.47826086956522
#
# FNB Name: Burger King Kota Damansara
# FNB Address: 27-1, Jalan PJU 5/13, Dataran Sunway, 47810 Petaling Jaya, Selangor
# Premise Name: BURGER KING KOTA DAMANSARA
# Premise Address: 27-1, JALAN PJU 5/13, DATARAN SUNWAY, KOTA DAMANSARA,
# Match Score: 100.0
#
# FNB Name: Burger King Lotus Bkt Puchong
# FNB Address: Lot No.G7, Lotus Extra Bandar Bukit Puchong PT 80259, Jalan BP 7, 1, Mukim, Bandar Bukit Puchong, 47120 Puchong, Selangor
# Premise Name: BURGER KING TESCO BANDAR BUKIT PUCHONG
# Premise Address: LOT NO.G7, TESCO BANDAR BUKIT PUCHONG, PT 80259, JALAN BP 7/1 BANDAR BUKIT PUCHONG, MUKIM PETALING
# Match Score: 87.83783783783784
#
# FNB Name: Burger King Olive Hill
# FNB Address: No: 49, Pusat Perniagaan Olive Hill, Jalan BS 1/3, Taman Bukit Serdang Section 1, 43300 Seri Kembangan, Selangor Darul Ehsan, 43300 Seri Kembangan, Selangor
# Premise Name: BURGER KING OLIVE HILL
# Premise Address: 49 (GF) PUSAT PERNIAGAAN OLIVE HILL, JALAN BS 1/3, TAMAN BUKIT SERDANG SEKSYEN 1 SERI KEMBANGAN
# Match Score: 94.30051813471502
#
# FNB Name: Burger King Petronas Mutiara Damansara
# FNB Address: No. 8 Jalan PJU 7/2, Bandar Mutiara Damansara, 47800 Petaling Jaya, Selangor Darul Ehsan, 47800 Petaling Jaya, Selangor
# Premise Name: BURGER KING MUTIARA DAMANSARA
# Premise Address: NO. 8, JALAN PJU 7/2 BANDAR MUTIARA DAMANSARA
# Match Score: 100.0
#
# FNB Name: Burger King Plaza Serdang Raya
# FNB Address: G18A, G18B, G19B (GF), Plaza Serdang Raya, Jln Serdang Raya, Tmn Serdang Raya, 43300 Seri Kembangan, Selangor
# Premise Name: BURGER KING PLAZA SERDANG RAYA
# Premise Address: LOT. G-18A, G-18B, G19A & G19B (GF), PLAZA SERDANG RAYA, SEKSYEN 7, SERI KEMBANGAN
# Match Score: 86.89655172413794
#
# FNB Name: Burger King SS12
# FNB Address: 4, Jalan SS12/1B, Ss 12, 47500 Subang Jaya, Selangor
# Premise Name: BURGER KING SS12
# Premise Address: 4 & 4A, JALAN SS 12/1B, SS 12, 47500 SUBANG JAYA SELANGOR
# Match Score: 96.12403100775194
#
# FNB Name: Burger King Shell Persiaran Sg Buloh
# FNB Address: Shell, 1, Persiaran Sungai Buloh, Taman Industri Sungai Buloh, 47810 Petaling Jaya, Selangor
# Premise Name: BURGER KING SHELL PERSIARAN SUNGAI BULOH
# Premise Address: SHELL PERSIARAN SG. BULOH, NO.1, PERSIARAN SG. BULOH, SUNGAI BULOH
# Match Score: 95.55555555555556

# %%
def merge_row(fnb_index, halal_row):
    columns = ['Premise Name', 'Company Brand Name', 'Halal Certification Expiry Date', 'Halal Certification Body']
    for col in columns:
        df_fnb.at[fnb_index, col] = halal_row[col]

# %%
# Official Flow

df_fnb = pd.read_csv('csv_data/fnb_list_part_2_cleaned.csv', encoding='utf-8')
df_halal = pd.read_csv('csv_data/premis_makanan_list_part_4_cleaned.csv', encoding='utf-8')

# Combine 'Name' and 'Address' into a single string for matching
df_fnb['Combined'] = df_fnb.apply(lambda row: normalize_text(row['Name'] + ' ' + normalize_text(row['Address'])), axis=1)
df_halal['Combined'] = df_halal.apply(lambda row: normalize_text(row['Premise Name'] + ' ' + normalize_text(row['Address'])), axis=1)

for col in ['Premise Name','Company Brand Name','Halal Certification Expiry Date','Halal Certification Body']:
    df_fnb[col] = None

THRESHOLD = 81.5

for fnb_index, fnb_row in tqdm(df_fnb.iterrows(), total=df_fnb.shape[0], desc="Searching for matches"):
    # Extract the combined field for the current row
    combined_fnb = fnb_row['Combined']
    
    # Perform fuzzy matching against the combined fields of df_halal
    best_match = process.extractOne(combined_fnb, df_halal['Combined'].tolist(), scorer=fuzz.token_set_ratio)
    
    # Check if the best match score meets the threshold
    if best_match and best_match[1] >= THRESHOLD:
        
        # Retrieve the matching row from df_halal
        halal_row = df_halal[df_halal['Combined'] == best_match[0]].iloc[0]

        normalized_fnb_name = normalize_text(fnb_row['Name'])
        normalized_fnb_address =  normalize_text(fnb_row['Address'])
        normalized_halal_name = normalize_text(halal_row['Premise Name'])
        normalized_halal_address =  normalize_text(halal_row['Address'])

        # Check if halal row address length is extremely shorter compared to fnb row address
        if len(fnb_row['Address'])/3 > len(halal_row['Address']):
            continue

        # Check if both fnb name and halal nama really no common words at all 
        if check_no_word_matches(normalized_fnb_name,normalized_halal_name) == True:
            continue
    
        # Check if fnb name and premise name are exactly the same
        if (normalized_fnb_name.replace(' ', '') == normalized_halal_name.replace(' ', '')):#fuzz.token_set_ratio(normalized_fnb_name, normalized_halal_name) >= 99) and ):
            merge_row(fnb_index, halal_row)
            continue

        # Check whether if the first two detected numbers in fnb address is equivalent to premise address
        first_two_numbers_in_fnb_address = find_first_two_numbers(normalized_fnb_address)
        first_two_numbers_in_halal_address = find_first_two_numbers(normalized_halal_address)
        # Check whether if the first number in fnb address is equivalent to premise address
        first_number_in_fnb_address = find_first_number(normalized_fnb_address)
        first_number_in_halal_address = find_first_number(normalized_halal_address)

        if (first_two_numbers_in_fnb_address != None and first_two_numbers_in_halal_address != None):
            if first_two_numbers_in_fnb_address == first_two_numbers_in_halal_address:
                merge_row(fnb_index, halal_row)
            continue
        
        if (first_number_in_fnb_address != None and first_number_in_halal_address != None):
            if first_number_in_fnb_address == first_number_in_halal_address:
                merge_row(fnb_index, halal_row)
            continue
# Out:
# Searching for matches: 100%|██████████| 4070/4070 [02:24<00:00, 28.21it/s]

# %%
display( df_fnb)
display( df_fnb.shape)
display( df_fnb.describe())
display( df_fnb.info)
# Out:
#                                   Name               Simplified Name  \
# 0                               #leleh                           NaN
# 1     1 Plus 1 Coffee • Fruit ( Café )              1 Plus 1 Coffee
# 2                   10 Pasento Puchong            10 Pasento Puchong
# 3                           103 Coffee                    103 Coffee
# 4                             128 Thai                      128 Thai
# ...                                ...                           ...
# 4065                 麻婆婆麻辣香锅·冒菜（SS15店）                       麻婆婆麻辣香锅
# 4066                               黄凳仔                           黄凳仔
# 4067      龍焱麻辣香锅 Loong Yan Mala Hotpot  龍焱麻辣香锅 Loong Yan Mala Hotpot
# 4068            𝗖𝗵𝗮𝗺𝗽𝗶𝗴𝗻𝗼𝗻𝘀 𝗣𝗮𝘁𝗶𝘀𝘀𝗲𝗿𝗶𝗲        𝗖𝗵𝗮𝗺𝗽𝗶𝗴𝗻𝗼𝗻𝘀 𝗣𝗮𝘁𝗶𝘀𝘀𝗲𝗿𝗶𝗲
# 4069              𝗧𝗮𝘀𝘁𝗲 𝗕𝘆 𝗖𝗵𝗮𝗺𝗽𝗶𝗴𝗻𝗼𝗻𝘀          𝗧𝗮𝘀𝘁𝗲 𝗕𝘆 𝗖𝗵𝗮𝗺𝗽𝗶𝗴𝗻𝗼𝗻𝘀
#
#               Category            Area                 Located In  \
# 0             ['Cafe']          Cheras     MyTOWN Shopping Centre
# 1             ['Cafe']         Puchong                        NaN
# 2             ['Cafe']         Puchong  Floor 1 · Hotel Sri Sutra
# 3             ['Cafe']  Seri Kembangan                        NaN
# 4     ['Western Food']     Subang Jaya                        NaN
# ...                ...             ...                        ...
# 4065  ['Chinese Food']     Subang Jaya                        NaN
# 4066  ['Chinese Food']  Seri Kembangan                        NaN
# 4067  ['Chinese Food']  Seri Kembangan                        NaN
# 4068       ['Dessert']   Petaling Jaya                        NaN
# 4069       ['Dessert']          Cheras                        NaN
#
#                                                 Address         Phone  \
# 0     Seksyen, 90, Jalan Cochrane, Cheras, 55100 Kua...  03-2720 1772
# 1     1, Jalan Puteri 7/11, Bandar Puteri, 47100 Puc...  016-934 7388
# 2     1st Floor, 10, Jalan Kenari 6, Bandar Puchong ...           NaN
# 3     103-G, Jalan Radin Bagus, Bandar Baru Sri Peta...  012-519 7103
# 4     42, Jalan SS 15/4c, Ss 15, 47500 Subang Jaya, ...  016-233 0609
# ...                                                 ...           ...
# 4065  Selangor, Subang Jaya, 1nd Floor 70, Jalan SS ...           NaN
# 4066  13-25, Jalan BS 3/6, Taman Bukit Serdang, 4330...           NaN
# 4067  8, Jalan PSK 4, Pusat Perdagangan Seri Kembang...  03-8958 5880
# 4068  27-1, Jalan PJU 5/11, Dataran Sunway, Kota Dam...  017-600 6710
# 4069  no 693, EkoCheras Mall, Lot G31, Ground floor,...  03-9134 9288
#
#                                          Google Map Url  \
# 0     https://www.google.com/maps/place/%23leleh/dat...
# 1     https://www.google.com/maps/place/1+Plus+1+Cof...
# 2     https://www.google.com/maps/place/10+Pasento+P...
# 3     https://www.google.com/maps/place/103+Coffee/d...
# 4     https://www.google.com/maps/place/128+Thai/dat...
# ...                                                 ...
# 4065  https://www.google.com/maps/place/%E9%BA%BB%E5...
# 4066  https://www.google.com/maps/place/%E9%BB%84%E5...
# 4067  https://www.google.com/maps/place/%E9%BE%8D%E7...
# 4068  https://www.google.com/maps/place/%F0%9D%97%96...
# 4069  https://www.google.com/maps/place/%F0%9D%97%A7...
#
#                                               Menu Url  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                 http://103coffeeworkshop.beepit.com/
# 4                                                  NaN
# ...                                                ...
# 4065                                               NaN
# 4066                                               NaN
# 4067                        https://wa.me//60389585880
# 4068      https://www.champignonspatisserie.com/en_MY/
# 4069  https://www.facebook.com/tastebychampignons/menu
#
#                                             Website Url  \
# 0                                                   NaN
# 1     http://web.facebook.com/profile.pho?id=1000844...
# 2                 https://www.instagram.com/10_pasento/
# 3                                https://103coffee.com/
# 4                 https://128thai.business.site/?m=true
# ...                                                 ...
# 4065                                                NaN
# 4066                                                NaN
# 4067                                                NaN
# 4068       https://www.champignonspatisserie.com/en_MY/
# 4069       https://www.facebook.com/tastebychampignons/
#
#                                               Order Url  \
# 0                                                   NaN
# 1     https://grab.onelink.me/2695613898?pid=inappsh...
# 2                                                   NaN
# 3                                                   NaN
# 4                  https://wa.me/message/EY3JJ7HNEGQ4G1
# ...                                                 ...
# 4065  https://www.foodpanda.my/restaurant/shtw/mapop...
# 4066                                                NaN
# 4067  https://www.foodpanda.my/restaurant/l4d2/loong...
# 4068                                                NaN
# 4069                                                NaN
#
#                                                Combined Premise Name  \
# 0     LELEH SEKSYEN 90 JALAN COCHRANE CHERAS 55100 K...         None
# 1     1 PLUS 1 COFFEE  FRUIT  CAFÉ  1 JALAN PUTERI 7...         None
# 2     10 PASENTO PUCHONG 1ST FLOOR 10 JALAN KENARI 6...         None
# 3     103 COFFEE 103G JALAN RADIN BAGUS BANDAR BARU ...         None
# 4     128 THAI 42 JALAN SS 154C SS 15 47500 SUBANG J...         None
# ...                                                 ...          ...
# 4065  麻婆婆麻辣香锅冒菜SS15店 SELANGOR SUBANG JAYA 1ND FLOOR ...         None
# 4066  黄凳仔 1325 JALAN BS 36 TAMAN BUKIT SERDANG 43300...         None
# 4067  龍焱麻辣香锅 LOONG YAN MALA HOTPOT 8 JALAN PSK 4 PUS...         None
# 4068  𝗖𝗵𝗮𝗺𝗽𝗶𝗴𝗻𝗼𝗻𝘀 𝗣𝗮𝘁𝗶𝘀𝘀𝗲𝗿𝗶𝗲 271 JALAN PJU 511 DATAR...         None
# 4069  𝗧𝗮𝘀𝘁𝗲 𝗕𝘆 𝗖𝗵𝗮𝗺𝗽𝗶𝗴𝗻𝗼𝗻𝘀 NO 693 EKOCHERAS MALL LOT...         None
#
#      Company Brand Name Halal Certification Expiry Date  \
# 0                  None                            None
# 1                  None                            None
# 2                  None                            None
# 3                  None                            None
# 4                  None                            None
# ...                 ...                             ...
# 4065               None                            None
# 4066               None                            None
# 4067               None                            None
# 4068               None                            None
# 4069               None                            None
#
#      Halal Certification Body
# 0                        None
# 1                        None
# 2                        None
# 3                        None
# 4                        None
# ...                       ...
# 4065                     None
# 4066                     None
# 4067                     None
# 4068                     None
# 4069                     None
#
# [4070 rows x 16 columns]
# (4070, 16)
#           Name  Simplified Name          Category         Area  \
# count     4070             4067              3926         4070
# unique    4070             3969                90            5
# top     #leleh  Baskin-Robbins   ['Chinese Food']  Subang Jaya
# freq         1               13               543          924
#
#                     Located In                             Address  \
# count                      957                                4055
# unique                     485                                3769
# top     MyTOWN Shopping Centre  Ss 15, 47500 Subang Jaya, Selangor
# freq                        22                                   6
#
#                 Phone                                     Google Map Url  \
# count            3451                                               4070
# unique           3214                                               4070
# top     1-300-88-2525  https://www.google.com/maps/place/%23leleh/dat...
# freq               22                                                  1
#
#                    Menu Url          Website Url           Order Url  \
# count                   624                 2083                1383
# unique                  516                 1665                1269
# top     https://kfc.com.my/  https://kfc.com.my/  http://kfc.com.my/
# freq                     22                   42                  24
#
#                                                  Combined    Premise Name  \
# count                                                4070             174
# unique                                               4070             171
# top     LELEH SEKSYEN 90 JALAN COCHRANE CHERAS 55100 K...  A&W DAMEN MALL
# freq                                                    1               2
#
#                                        Company Brand Name  \
# count                                                 174
# unique                                                 54
# top     GERBANG ALAF RESTAURANTS SDN BHD (FORMERLY KNO...
# freq                                                   19
#
#        Halal Certification Expiry Date  \
# count                              173
# unique                              65
# top                         2024-06-15
# freq                                16
#
#                        Halal Certification Body
# count                                       174
# unique                                        1
# top     JABATAN KEMAJUAN ISLAM MALAYSIA (JAKIM)
# freq                                        174
# <bound method DataFrame.info of                                   Name               Simplified Name  \
# 0                               #leleh                           NaN
# 1     1 Plus 1 Coffee • Fruit ( Café )              1 Plus 1 Coffee
# 2                   10 Pasento Puchong            10 Pasento Puchong
# 3                           103 Coffee                    103 Coffee
# 4                             128 Thai                      128 Thai
# ...                                ...                           ...
# 4065                 麻婆婆麻辣香锅·冒菜（SS15店）                       麻婆婆麻辣香锅
# 4066                               黄凳仔                           黄凳仔
# 4067      龍焱麻辣香锅 Loong Yan Mala Hotpot  龍焱麻辣香锅 Loong Yan Mala Hotpot
# 4068            𝗖𝗵𝗮𝗺𝗽𝗶𝗴𝗻𝗼𝗻𝘀 𝗣𝗮𝘁𝗶𝘀𝘀𝗲𝗿𝗶𝗲        𝗖𝗵𝗮𝗺𝗽𝗶𝗴𝗻𝗼𝗻𝘀 𝗣𝗮𝘁𝗶𝘀𝘀𝗲𝗿𝗶𝗲
# 4069              𝗧𝗮𝘀𝘁𝗲 𝗕𝘆 𝗖𝗵𝗮𝗺𝗽𝗶𝗴𝗻𝗼𝗻𝘀          𝗧𝗮𝘀𝘁𝗲 𝗕𝘆 𝗖𝗵𝗮𝗺𝗽𝗶𝗴𝗻𝗼𝗻𝘀
#
#               Category            Area                 Located In  \
# 0             ['Cafe']          Cheras     MyTOWN Shopping Centre
# 1             ['Cafe']         Puchong                        NaN
# 2             ['Cafe']         Puchong  Floor 1 · Hotel Sri Sutra
# 3             ['Cafe']  Seri Kembangan                        NaN
# 4     ['Western Food']     Subang Jaya                        NaN
# ...                ...             ...                        ...
# 4065  ['Chinese Food']     Subang Jaya                        NaN
# 4066  ['Chinese Food']  Seri Kembangan                        NaN
# 4067  ['Chinese Food']  Seri Kembangan                        NaN
# 4068       ['Dessert']   Petaling Jaya                        NaN
# 4069       ['Dessert']          Cheras                        NaN
#
#                                                 Address         Phone  \
# 0     Seksyen, 90, Jalan Cochrane, Cheras, 55100 Kua...  03-2720 1772
# 1     1, Jalan Puteri 7/11, Bandar Puteri, 47100 Puc...  016-934 7388
# 2     1st Floor, 10, Jalan Kenari 6, Bandar Puchong ...           NaN
# 3     103-G, Jalan Radin Bagus, Bandar Baru Sri Peta...  012-519 7103
# 4     42, Jalan SS 15/4c, Ss 15, 47500 Subang Jaya, ...  016-233 0609
# ...                                                 ...           ...
# 4065  Selangor, Subang Jaya, 1nd Floor 70, Jalan SS ...           NaN
# 4066  13-25, Jalan BS 3/6, Taman Bukit Serdang, 4330...           NaN
# 4067  8, Jalan PSK 4, Pusat Perdagangan Seri Kembang...  03-8958 5880
# 4068  27-1, Jalan PJU 5/11, Dataran Sunway, Kota Dam...  017-600 6710
# 4069  no 693, EkoCheras Mall, Lot G31, Ground floor,...  03-9134 9288
#
#                                          Google Map Url  \
# 0     https://www.google.com/maps/place/%23leleh/dat...
# 1     https://www.google.com/maps/place/1+Plus+1+Cof...
# 2     https://www.google.com/maps/place/10+Pasento+P...
# 3     https://www.google.com/maps/place/103+Coffee/d...
# 4     https://www.google.com/maps/place/128+Thai/dat...
# ...                                                 ...
# 4065  https://www.google.com/maps/place/%E9%BA%BB%E5...
# 4066  https://www.google.com/maps/place/%E9%BB%84%E5...
# 4067  https://www.google.com/maps/place/%E9%BE%8D%E7...
# 4068  https://www.google.com/maps/place/%F0%9D%97%96...
# 4069  https://www.google.com/maps/place/%F0%9D%97%A7...
#
#                                               Menu Url  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                 http://103coffeeworkshop.beepit.com/
# 4                                                  NaN
# ...                                                ...
# 4065                                               NaN
# 4066                                               NaN
# 4067                        https://wa.me//60389585880
# 4068      https://www.champignonspatisserie.com/en_MY/
# 4069  https://www.facebook.com/tastebychampignons/menu
#
#                                             Website Url  \
# 0                                                   NaN
# 1     http://web.facebook.com/profile.pho?id=1000844...
# 2                 https://www.instagram.com/10_pasento/
# 3                                https://103coffee.com/
# 4                 https://128thai.business.site/?m=true
# ...                                                 ...
# 4065                                                NaN
# 4066                                                NaN
# 4067                                                NaN
# 4068       https://www.champignonspatisserie.com/en_MY/
# 4069       https://www.facebook.com/tastebychampignons/
#
#                                               Order Url  \
# 0                                                   NaN
# 1     https://grab.onelink.me/2695613898?pid=inappsh...
# 2                                                   NaN
# 3                                                   NaN
# 4                  https://wa.me/message/EY3JJ7HNEGQ4G1
# ...                                                 ...
# 4065  https://www.foodpanda.my/restaurant/shtw/mapop...
# 4066                                                NaN
# 4067  https://www.foodpanda.my/restaurant/l4d2/loong...
# 4068                                                NaN
# 4069                                                NaN
#
#                                                Combined Premise Name  \
# 0     LELEH SEKSYEN 90 JALAN COCHRANE CHERAS 55100 K...         None
# 1     1 PLUS 1 COFFEE  FRUIT  CAFÉ  1 JALAN PUTERI 7...         None
# 2     10 PASENTO PUCHONG 1ST FLOOR 10 JALAN KENARI 6...         None
# 3     103 COFFEE 103G JALAN RADIN BAGUS BANDAR BARU ...         None
# 4     128 THAI 42 JALAN SS 154C SS 15 47500 SUBANG J...         None
# ...                                                 ...          ...
# 4065  麻婆婆麻辣香锅冒菜SS15店 SELANGOR SUBANG JAYA 1ND FLOOR ...         None
# 4066  黄凳仔 1325 JALAN BS 36 TAMAN BUKIT SERDANG 43300...         None
# 4067  龍焱麻辣香锅 LOONG YAN MALA HOTPOT 8 JALAN PSK 4 PUS...         None
# 4068  𝗖𝗵𝗮𝗺𝗽𝗶𝗴𝗻𝗼𝗻𝘀 𝗣𝗮𝘁𝗶𝘀𝘀𝗲𝗿𝗶𝗲 271 JALAN PJU 511 DATAR...         None
# 4069  𝗧𝗮𝘀𝘁𝗲 𝗕𝘆 𝗖𝗵𝗮𝗺𝗽𝗶𝗴𝗻𝗼𝗻𝘀 NO 693 EKOCHERAS MALL LOT...         None
#
#      Company Brand Name Halal Certification Expiry Date  \
# 0                  None                            None
# 1                  None                            None
# 2                  None                            None
# 3                  None                            None
# 4                  None                            None
# ...                 ...                             ...
# 4065               None                            None
# 4066               None                            None
# 4067               None                            None
# 4068               None                            None
# 4069               None                            None
#
#      Halal Certification Body
# 0                        None
# 1                        None
# 2                        None
# 3                        None
# 4                        None
# ...                       ...
# 4065                     None
# 4066                     None
# 4067                     None
# 4068                     None
# 4069                     None
#
# [4070 rows x 16 columns]>

# %%
# Sort by 'FnB name' alphabetically and then by the presence of 'Premise Name' (non-null values first)
import ast
df_fnb = pd.read_csv('csv_data/fnb_list_part_6_merged.csv', encoding='utf-8')

def get_categories_count(row):
    # Check if 'Category' is NaN or contains 'Fast Food'
    if pd.isna(row['Category']) or 'Fast Food' in row['Category']:
        return 0, np.nan  # Set a flag for sorting and keep category count as NaN
    else:
        category_array = ast.literal_eval(row['Category'])
        return 1, len(category_array)  # Flag for absence of 'Fast Food' and count items

# Apply the helper function
df_fnb[['Has Fast Food', 'Categories Count']] = df_fnb.apply(lambda row: get_categories_count(row), axis=1, result_type="expand")

# Sort by 'No Fast Food' (descending), 'Category Count' (descending, nulls last), 'Premise Name' (nulls last), and 'Name' (ascending)
df_fnb_sorted = df_fnb.sort_values(by=['Categories Count','Premise Name','Has Fast Food', 'Name'], 
                                   ascending=[False, False, False, True], 
                                   na_position='last')

df_fnb_sorted.drop(columns=['Combined', 'Has Fast Food', 'Categories Count'], inplace=True)

display(df_fnb_sorted.head(20))
# Out:
#                                 Name                 Simplified Name  \
# 1269     Iron Chef House (non halal)                Iron Chef House
# 354            Big Family Restaurant           Big Family Restaurant
# 1824           May Keng Cafe Sdn Bhd           May Keng Cafe Sdn Bhd
# 2072              Nasi Kandar Pelita              Nasi Kandar Pelita
# 153       All Want To Eat Restaurant      All Want To Eat Restaurant
# 332   Belly & The Chef Cafe (Cheras)          Belly & The Chef Cafe
# 523                    Canai 15 Cafè                   Canai 15 Cafè
# 556      Chef Ammar Xpress Souk Cafe     Chef Ammar Xpress Souk Cafe
# 733            Day 9 Kitchen Cafe 明明           Day 9 Kitchen Cafe 明明
# 1043  Good Friends Restaurant & Cafe  Good Friends Restaurant & Cafe
# 1140             Happy Ok Restaurant             Happy Ok Restaurant
# 1225          ICON BREWINGS @ CHERAS                  ICON BREWINGS
# 1461                     Kaki Corner                     Kaki Corner
# 1465        Kam Yat Restaurant 金壹私房菜        Kam Yat Restaurant 金壹私房菜
# 1584       LAKEVIEW CAFE مطعم وكافية       LAKEVIEW CAFE مطعم وكافية
# 1667   Lil' Bird & The Big Bear Cafe   Lil' Bird & The Big Bear Cafe
# 1796   Mani Curry House @ Olive Hill               Mani Curry House
# 1989           Murni Discovery USJ 9           Murni Discovery USJ 9
# 2351          Q Bistro @ Subang jaya                       Q Bistro
# 2634             Restoran Happy Town             Restoran Happy Town
#
#                                                Category            Area  \
# 1269  ['Western Food', 'Cafe', 'Malay Food', 'Chines...  Seri Kembangan
# 354   ['Western Food', 'Middle Eastern Food', 'Chine...     Subang Jaya
# 1824  ['Western Food', 'Cafe', 'Chinese Food', 'Mala...  Seri Kembangan
# 2072  ['Indian Food', 'Middle Eastern Food', 'Malay ...     Subang Jaya
# 153      ['Western Food', 'Chinese Food', 'Malay Food']  Seri Kembangan
# 332                 ['Western Food', 'Cafe', 'Dessert']          Cheras
# 523   ['Western Food', 'Indian Food', 'Vegetarian Fo...     Subang Jaya
# 556     ['Western Food', 'Cafe', 'Middle Eastern Food']     Subang Jaya
# 733           ['Western Food', 'Cafe', 'Japanese Food']  Seri Kembangan
# 1043    ['Western Food', 'Cafe', 'Middle Eastern Food']     Subang Jaya
# 1140     ['Western Food', 'Chinese Food', 'Malay Food']  Seri Kembangan
# 1225                ['Western Food', 'Cafe', 'Dessert']          Cheras
# 1461             ['Western Food', 'Cafe', 'Malay Food']          Cheras
# 1465  ['Western Food', 'Chinese Food', 'Vegetarian F...  Seri Kembangan
# 1584    ['Western Food', 'Cafe', 'Middle Eastern Food']  Seri Kembangan
# 1667        ['Western Food', 'Cafe', 'Vegetarian Food']     Subang Jaya
# 1796   ['Malay Food', 'Indian Food', 'Vegetarian Food']  Seri Kembangan
# 1989  ['Western Food', 'Vegetarian Food', 'Malay Food']     Subang Jaya
# 2351   ['Malay Food', 'Indian Food', 'Vegetarian Food']     Subang Jaya
# 2634  ['Middle Eastern Food', 'Chinese Food', 'Veget...     Subang Jaya
#
#                              Located In  \
# 1269  Floor 2 · The Mines Shopping Mall
# 354                                 NaN
# 1824                                NaN
# 2072                                NaN
# 153                                 NaN
# 332                                 NaN
# 523                      Sunway Pyramid
# 556                                 NaN
# 733                                 NaN
# 1043                                NaN
# 1140                                NaN
# 1225                                NaN
# 1461                                NaN
# 1465                                NaN
# 1584                       The Heritage
# 1667                      Subang Parade
# 1796           Olive Hill Business Park
# 1989                                NaN
# 2351                                NaN
# 2634                                NaN
#
#                                                 Address         Phone  \
# 1269  E-2-G,E-3-G,E-4-G &E-5-G, Jalan PP 25, Putra W...  03-9544 4793
# 354   2, Jalan SS 15/4b, Ss 15, 47500 Subang Jaya, S...  012-305 9350
# 1824  1-1, Jalan SP 2/4, Taman Serdang Perdana, 4330...  03-8943 8070
# 2072  2, Jalan SS 15/4c, Ss 15, 47500 Subang Jaya, S...  03-5632 5532
# 153   No. 192, Jalan SK 7/11, Kampung Baru Seri Kemb...  012-366 6863
# 332   13, Lorong Durian, Taman Cheras, 56100 Kuala L...  012-527 3966
# 523   99, Jalan SS 14/1, Ss 14, 47500 Subang Jaya, S...  03-5611 8426
# 556   16, Jalan USJ 4/1, Usj 4, 47600 Subang Jaya, S...  03-8011 8073
# 733   3-1, Jalan Equine 10B, Taman Equine, 43300 Ser...  016-616 0590
# 1043  55, Jalan SS 15/8a, Ss 15, 47500 Subang Jaya, ...  03-5613 1415
# 1140  Jalan BS 5/26b, Taman Bukit Serdang, 43300 Ser...           NaN
# 1225  24, Jalan Manis 3, Taman Bukit Segar, 56100 Ch...  03-2856 2999
# 1461  No. 20 & 22, Jalan Siput Akek, Taman Billion, ...  012-200 3432
# 1465  21, Jalan PSK 6, Pusat Perdagangan Seri Kemban...  017-911 9278
# 1584    Jalan Dagang Sb, 43300 Seri Kembangan, Selangor  03-8655 3670
# 1667  24, Jalan USJ 10/1B, Taipan Business Centre, 4...  03-8011 6311
# 1796  No 1G, Jalan BS1/3 Olive Hill Business Park, T...  03-8958 5155
# 1989  39-1 & 41, 1, Jalan USJ 9/5p, Subang Business ...  017-755 7308
# 2351  Lot No, 103, Jalan SS 15/4c, Ss 15, 47500 Suba...  03-5611 2472
# 2634  97, Jalan SS 15/4b, Ss 15, 47500 Subang Jaya, ...  012-565 5117
#
#                                          Google Map Url  \
# 1269  https://www.google.com/maps/place/Iron+Chef+Ho...
# 354   https://www.google.com/maps/place/Big+Family+R...
# 1824  https://www.google.com/maps/place/May+Keng+Caf...
# 2072  https://www.google.com/maps/place/Nasi+Kandar+...
# 153   https://www.google.com/maps/place/All+Want+To+...
# 332   https://www.google.com/maps/place/Belly+%26+Th...
# 523   https://www.google.com/maps/place/Canai+15+Caf...
# 556   https://www.google.com/maps/place/Chef+Ammar+X...
# 733   https://www.google.com/maps/place/Day+9+Kitche...
# 1043  https://www.google.com/maps/place/Good+Friends...
# 1140  https://www.google.com/maps/place/Happy+Ok+Res...
# 1225  https://www.google.com/maps/place/ICON+BREWING...
# 1461  https://www.google.com/maps/place/Kaki+Corner/...
# 1465  https://www.google.com/maps/place/Kam+Yat+Rest...
# 1584  https://www.google.com/maps/place/LAKEVIEW+CAF...
# 1667  https://www.google.com/maps/place/Lil%27+Bird+...
# 1796  https://www.google.com/maps/place/Mani+Curry+H...
# 1989  https://www.google.com/maps/place/Murni+Discov...
# 2351  https://www.google.com/maps/place/Q+Bistro+@+S...
# 2634  https://www.google.com/maps/place/Restoran+Hap...
#
#                                                Menu Url  \
# 1269                                                NaN
# 354                                                 NaN
# 1824                                                NaN
# 2072                                                NaN
# 153                                                 NaN
# 332                   https://linktr.ee/bellyandthechef
# 523   https://food.grab.com/my/en/restaurant/canai-c...
# 556                                                 NaN
# 733   https://grab.onelink.me/2695613898?pid=inappsh...
# 1043                 http://www.goodfriendscafe.com.my/
# 1140                                                NaN
# 1225            https://iconbrewings.justorder.today/v2
# 1461                                                NaN
# 1465                                                NaN
# 1584                                                NaN
# 1667                                                NaN
# 1796                                                NaN
# 1989                                                NaN
# 2351  https://online.qbistro.com/directory/brand/571...
# 2634                                                NaN
#
#                                             Website Url  \
# 1269                       https://www.pizzahut.com.my/
# 354   https://www.facebook.com/%E5%A4%A7%E5%AE%B6%E7...
# 1824                                                NaN
# 2072                          http://www.pelita.com.my/
# 153                                                 NaN
# 332                   https://linktr.ee/bellyandthechef
# 523   https://canai-15-cafe-taste-of-india.business....
# 556                        http://www.chefammar.com.my/
# 733           https://www.facebook.com/mingday9kitchen/
# 1043                 http://www.goodfriendscafe.com.my/
# 1140                                                NaN
# 1225              https://iconbrewings.justorder.today/
# 1461  https://www.facebook.com/pages/Kaki-Corner/169...
# 1465                                                NaN
# 1584                                                NaN
# 1667                        https://lilbirdbigbear.com/
# 1796                                                NaN
# 1989                     http://www.murnidiscovery.com/
# 2351            https://qbistro.com/store-locator/ss15/
# 2634                                                NaN
#
#                                               Order Url  \
# 1269  https://www.foodpanda.my/restaurant/m7ax/pizza...
# 354   https://www.foodpanda.my/restaurant/l7vz/pork-...
# 1824                                                NaN
# 2072  https://www.foodpanda.my/restaurant/o1im/nasi-...
# 153   https://www.foodpanda.my/restaurant/n1cx/all-w...
# 332                   https://linktr.ee/bellyandthechef
# 523                                                 NaN
# 556                                                 NaN
# 733   https://grab.onelink.me/2695613898?pid=inappsh...
# 1043                                                NaN
# 1140                                                NaN
# 1225  https://weborder.zeoniq.com/?parameters=MDMwNT...
# 1461                                                NaN
# 1465  https://www.foodpanda.my/restaurant/f5fu/kam-y...
# 1584  https://www.foodpanda.my/restaurant/m0la/lake-...
# 1667                 https://lilbirdbigbear.beepit.com/
# 1796  https://www.foodpanda.my/restaurant/p4cn/mani-...
# 1989                                                NaN
# 2351  https://www.foodpanda.my/restaurant/n2vm/q-bis...
# 2634  https://www.foodpanda.my/restaurant/p4uf/origi...
#
#                           Premise Name          Company Brand Name  \
# 1269                               NaN                         NaN
# 354                                NaN                         NaN
# 1824                               NaN                         NaN
# 2072  NASI KANDAR PELITA (SUBANG JAYA)  NASI KANDAR PELITA SDN BHD
# 153                                NaN                         NaN
# 332                                NaN                         NaN
# 523                                NaN                         NaN
# 556                                NaN                         NaN
# 733                                NaN                         NaN
# 1043                               NaN                         NaN
# 1140                               NaN                         NaN
# 1225                               NaN                         NaN
# 1461                               NaN                         NaN
# 1465                               NaN                         NaN
# 1584                               NaN                         NaN
# 1667                               NaN                         NaN
# 1796                               NaN                         NaN
# 1989                               NaN                         NaN
# 2351                               NaN                         NaN
# 2634                               NaN                         NaN
#
#      Halal Certification Expiry Date                 Halal Certification Body
# 1269                             NaN                                      NaN
# 354                              NaN                                      NaN
# 1824                             NaN                                      NaN
# 2072                      2020-07-15  JABATAN KEMAJUAN ISLAM MALAYSIA (JAKIM)
# 153                              NaN                                      NaN
# 332                              NaN                                      NaN
# 523                              NaN                                      NaN
# 556                              NaN                                      NaN
# 733                              NaN                                      NaN
# 1043                             NaN                                      NaN
# 1140                             NaN                                      NaN
# 1225                             NaN                                      NaN
# 1461                             NaN                                      NaN
# 1465                             NaN                                      NaN
# 1584                             NaN                                      NaN
# 1667                             NaN                                      NaN
# 1796                             NaN                                      NaN
# 1989                             NaN                                      NaN
# 2351                             NaN                                      NaN
# 2634                             NaN                                      NaN

# %%
df_fnb_sorted.to_csv('csv_data/fnb_list_part_6_merged_final.csv', index=False, encoding='utf-8')
