# %%
import pandas as pd
import numpy as np
import ast

# %%
file_path = '../csv_data/fnb_list_part_7_reviews.csv'
df = pd.read_csv(file_path, encoding='utf-8')
display(df['Category'].isna().sum())
display(df.head(10))
# Out:
# 144
#                              Name                 Simplified Name  \
# 0     Iron Chef House (non halal)                Iron Chef House
# 1           Big Family Restaurant           Big Family Restaurant
# 2           May Keng Cafe Sdn Bhd           May Keng Cafe Sdn Bhd
# 3              Nasi Kandar Pelita              Nasi Kandar Pelita
# 4      All Want To Eat Restaurant      All Want To Eat Restaurant
# 5  Belly & The Chef Cafe (Cheras)          Belly & The Chef Cafe
# 6                   Canai 15 Cafè                   Canai 15 Cafè
# 7     Chef Ammar Xpress Souk Cafe     Chef Ammar Xpress Souk Cafe
# 8           Day 9 Kitchen Cafe 明明           Day 9 Kitchen Cafe 明明
# 9  Good Friends Restaurant & Cafe  Good Friends Restaurant & Cafe
#
#                                             Category            Area  \
# 0  ['Western Food', 'Cafe', 'Chinese Food', 'Japa...  Seri Kembangan
# 1  ['Western Food', 'Middle Eastern Food', 'Chine...     Subang Jaya
# ...

# %%
import ast

# Assuming df is your DataFrame and 'Category' is the column containing the string representation of a list
category_string = df['Category'].iloc[0]

# Parse the string representation of the list into an actual list
category_list = ast.literal_eval(category_string)

# Print the resulting list
print(category_list)
# Out:
# ['Western Food', 'Cafe', 'Malay Food', 'Chinese Food', 'Japanese Food']
